# %% [markdown]
# # Face expression recognition

# %%
from google.colab import drive
import zipfile
import os

# Google 드라이브 마운트
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ZIP 파일 경로 및 압축 해제될 경로 설정
zip_file_path = '/content/drive/MyDrive/ESAA_OB/face.zip'  # ZIP 파일 경로
extract_path = 'dataset/'  # 압축 해제될 경로

# 압축 해제
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
folder_path = "/content/dataset/images/" # 이미지 데이터의 기본 경로

# %% [markdown]
# 이미지 시각화 및 데이터 살펴보기

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img
pic_size = 48

# 특정 감정에 대한 이미지를 시각화하는 함수
def plot_exp(expression):
    plt.figure(figsize= (12,12))
    for i in range(1, 10, 1):
        plt.subplot(3,3,i)

        img = load_img(folder_path+"train/"+expression+"/"+
                  os.listdir(folder_path + "train/" + expression)[i], target_size=(pic_size, pic_size))

        plt.imshow(img)
    plt.show()

# %%
# 여러 표정에 대한 이미지를 한 번에 시각화하는 함수
def plot_all_expressions(folder_path, expressions):
    for expression in expressions: # 표정 리스트
        print(f"Showing images for: {expression}")
        plot_exp(expression)

# %%
expressions = ['happy', 'sad', 'angry', 'neutral', 'surprise', 'fear', 'disgust']
plot_all_expressions(folder_path, expressions)
# Out:
# Showing images for: happy
# Showing images for: sad
# Showing images for: angry
# Showing images for: neutral
# Showing images for: surprise
# Showing images for: fear
# Showing images for: disgust

# %% [markdown]
# 표정별 이미지 개수

# %%
categories = []
counts = []

for expression in os.listdir(folder_path + "train"):
    count = len(os.listdir(folder_path + "train/" + expression))
    categories.append(expression)
    counts.append(count)
    print(f"{count} {expression} images")

plt.figure(figsize = (10, 6))
plt.bar(categories, counts, color = "skyblue")
plt.title("Number of Images by Category")
plt.xlabel("Category")
plt.ylabel("Number of Images")
plt.xticks(rotation=45)
plt.show()
# Out:
# 3205 surprise images
# 4982 neutral images
# 3993 angry images
# 7164 happy images
# 436 disgust images
# 4938 sad images
# 4103 fear images

# %%
categories = []
counts = []

for expression in os.listdir(folder_path + "validation"):
    count = len(os.listdir(folder_path + "validation/" + expression))
    categories.append(expression)
    counts.append(count)
    print(f"{count} {expression} images")

plt.figure(figsize = (10, 6))
plt.bar(categories, counts, color = "skyblue")
plt.title("Number of Images by Category")
plt.xlabel("Category")
plt.ylabel("Number of Images")
plt.xticks(rotation=45)
plt.show()
# Out:
# 797 surprise images
# 1216 neutral images
# 960 angry images
# 1825 happy images
# 111 disgust images
# 1139 sad images
# 1018 fear images

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

# %%
train_datagen = ImageDataGenerator(rescale = 1./255., #정규화
                                   rotation_range = 40, #회전
                                   width_shift_range = 0.2, #위치(좌우)
                                   height_shift_range = 0.2, #위치(상하)
                                   shear_range = 0.2, #전단 변형(밀림)
                                   zoom_range = 0.2, #확대, 축소
                                   horizontal_flip = True #수평으로 뒤집음)

test_datagen = ImageDataGenerator(rescale = 1.0/255.)

train_generator = train_datagen.flow_from_directory(folder_path + "train",
                                                    target_size = (pic_size, pic_size),
                                                    color_mode = "rgb",
                                                    batch_size = 128,
                                                    class_mode = "categorical",
                                                    shuffle = True)

test_generator = test_datagen.flow_from_directory(folder_path + "validation",
                                                  target_size = (pic_size, pic_size),
                                                  color_mode = "rgb",
                                                  batch_size = 128,
                                                  class_mode = "categorical",
                                                  shuffle = False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# -> ImageDataGenerator 역할
# >
# CNN은 영상의 2차원 변환인 회전(Rotation), 크기(Scale), 밀림(Shearing), 반사(Reflection), 이동(Translation)과 같은 2차원 변환인 Affine Transform에 취약하여 변환된 사진 또는 영상을 다른 자료로 인식한다.
# ImageDataGenerator는 Noise삽입, 색상, 밝기 변형 등을 활용하여 실시간으로 데이터 증강을 사용하고, 텐서 이미지 데이터 배치를 생성하여 데이터 학습의 정확도를 높이는 역할을 한다.

# %% [markdown]
# ## CNN

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Activation, Flatten, Dense, Dropout
from keras.optimizers import Adam

n_classes = 7

#layer 1
model = Sequential()
model.add(Conv2D(64,(3,3),padding='same',input_shape=(48,48,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#layer 2
model.add(Conv2D(128,(5,5),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#layer 3
model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#layer 4
model.add(Conv2D(512,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

#FC Layer 1
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

#FC Layer 2
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(n_classes,activation='softmax'))
opt = Adam(lr = 0.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        1792
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Bat  (None, 12, 12, 512)       2048
#  chNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 512)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Bat  (None, 6, 6, 512)         2048
#  chNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 512)         0
#
#  max_pooling2d_3 (MaxPoolin  (None, 3, 3, 512)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Bat  (None, 512)               2048
#  chNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4479879 (17.09 MB)
# Trainable params: 4475911 (17.07 MB)
# Non-trainable params: 3968 (15.50 KB)
# _________________________________________________________________

# %%
# 모델 구조
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes = True)

# %%
epochs = 48
from keras.callbacks import ModelCheckpoint

# 모델 체크포인트 콜백 설정
checkpoint = ModelCheckpoint(
    "model_weights.h5",
    monitor="val_accuracy",  # 'val_accuracy'로 변경
    verbose=1,
    save_best_only=True,
    mode="max"
)

callbacks_list = [checkpoint]

# 모델 훈련
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/48
# 225/225 [==============================] - ETA: 0s - loss: 1.9399 - accuracy: 0.2237
# Epoch 1: val_accuracy improved from -inf to 0.25923, saving model to model_weights.h5
# 225/225 [==============================] - 58s 212ms/step - loss: 1.9399 - accuracy: 0.2237 - val_loss: 1.8608 - val_accuracy: 0.2592
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/48
# 225/225 [==============================] - ETA: 0s - loss: 1.8517 - accuracy: 0.2391
# Epoch 2: val_accuracy improved from 0.25923 to 0.25952, saving model to model_weights.h5
# 225/225 [==============================] - 52s 229ms/step - loss: 1.8517 - accuracy: 0.2391 - val_loss: 1.8527 - val_accuracy: 0.2595
# Epoch 3/48
# 225/225 [==============================] - ETA: 0s - loss: 1.8006 - accuracy: 0.2555
# Epoch 3: val_accuracy improved from 0.25952 to 0.29105, saving model to model_weights.h5
# 225/225 [==============================] - 47s 209ms/step - loss: 1.8006 - accuracy: 0.2555 - val_loss: 1.7302 - val_accuracy: 0.2911
# Epoch 4/48
# 225/225 [==============================] - ETA: 0s - loss: 1.7410 - accuracy: 0.2915
# Epoch 4: val_accuracy did not improve from 0.29105
# 225/225 [==============================] - 47s 208ms/step - loss: 1.7410 - accuracy: 0.2915 - val_loss: 1.9027 - val_accuracy: 0.2842
# Epoch 5/48
# 225/225 [==============================] - ETA: 0s - loss: 1.6704 - accuracy: 0.3318
# Epoch 5: val_accuracy improved from 0.29105 to 0.38423, saving model to model_weights.h5
# 225/225 [==============================] - 47s 207ms/step - loss: 1.6704 - accuracy: 0.3318 - val_loss: 1.6627 - val_accuracy: 0.3842
# Epoch 6/48
# 225/225 [==============================] - ETA: 0s - loss: 1.5933 - accuracy: 0.3701
# Epoch 6: val_accuracy improved from 0.38423 to 0.44474, saving model to model_weights.h5
# 225/225 [==============================] - 47s 208ms/step - loss: 1.5933 - accuracy: 0.3701 - val_loss: 1.4313 - val_accuracy: 0.4447
# Epoch 7/48
# 225/225 [==============================] - ETA: 0s - loss: 1.5249 - accuracy: 0.4093
# Epoch 7: val_accuracy did not improve from 0.44474
# 225/225 [==============================] - 47s 207ms/step - loss: 1.5249 - accuracy: 0.4093 - val_loss: 1.6773 - val_accuracy: 0.3247
# Epoch 8/48
# 225/225 [==============================] - ETA: 0s - loss: 1.4701 - accuracy: 0.4315
# Epoch 8: val_accuracy did not improve from 0.44474
# 225/225 [==============================] - 47s 210ms/step - loss: 1.4701 - accuracy: 0.4315 - val_loss: 1.4915 - val_accuracy: 0.4153
# Epoch 9/48
# 225/225 [==============================] - ETA: 0s - loss: 1.4250 - accuracy: 0.4493
# Epoch 9: val_accuracy improved from 0.44474 to 0.49205, saving model to model_weights.h5
# 225/225 [==============================] - 47s 210ms/step - loss: 1.4250 - accuracy: 0.4493 - val_loss: 1.3358 - val_accuracy: 0.4920
# Epoch 10/48
# 225/225 [==============================] - ETA: 0s - loss: 1.3827 - accuracy: 0.4698
# Epoch 10: val_accuracy improved from 0.49205 to 0.49929, saving model to model_weights.h5
# 225/225 [==============================] - 47s 209ms/step - loss: 1.3827 - accuracy: 0.4698 - val_loss: 1.2816 - val_accuracy: 0.4993
# Epoch 11/48
# 225/225 [==============================] - ETA: 0s - loss: 1.3570 - accuracy: 0.4773
# Epoch 11: val_accuracy improved from 0.49929 to 0.52443, saving model to model_weights.h5
# 225/225 [==============================] - 47s 209ms/step - loss: 1.3570 - accuracy: 0.4773 - val_loss: 1.2308 - val_accuracy: 0.5244
# Epoch 12/48
# 225/225 [==============================] - ETA: 0s - loss: 1.3288 - accuracy: 0.4903
# Epoch 12: val_accuracy improved from 0.52443 to 0.52997, saving model to model_weights.h5
# 225/225 [==============================] - 47s 209ms/step - loss: 1.3288 - accuracy: 0.4903 - val_loss: 1.2008 - val_accuracy: 0.5300
# Epoch 13/48
# 225/225 [==============================] - ETA: 0s - loss: 1.3052 - accuracy: 0.4970
# Epoch 13: val_accuracy did not improve from 0.52997
# 225/225 [==============================] - 47s 208ms/step - loss: 1.3052 - accuracy: 0.4970 - val_loss: 1.2614 - val_accuracy: 0.5135
# Epoch 14/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2844 - accuracy: 0.5058
# Epoch 14: val_accuracy did not improve from 0.52997
# 225/225 [==============================] - 46s 206ms/step - loss: 1.2844 - accuracy: 0.5058 - val_loss: 1.3011 - val_accuracy: 0.4912
# Epoch 15/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2779 - accuracy: 0.5085
# Epoch 15: val_accuracy improved from 0.52997 to 0.54560, saving model to model_weights.h5
# 225/225 [==============================] - 47s 210ms/step - loss: 1.2779 - accuracy: 0.5085 - val_loss: 1.1693 - val_accuracy: 0.5456
# Epoch 16/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2597 - accuracy: 0.5135
# Epoch 16: val_accuracy improved from 0.54560 to 0.54602, saving model to model_weights.h5
# 225/225 [==============================] - 58s 259ms/step - loss: 1.2597 - accuracy: 0.5135 - val_loss: 1.1941 - val_accuracy: 0.5460
# Epoch 17/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2507 - accuracy: 0.5200
# Epoch 17: val_accuracy improved from 0.54602 to 0.54986, saving model to model_weights.h5
# 225/225 [==============================] - 47s 208ms/step - loss: 1.2507 - accuracy: 0.5200 - val_loss: 1.1873 - val_accuracy: 0.5499
# Epoch 18/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2323 - accuracy: 0.5297
# Epoch 18: val_accuracy improved from 0.54986 to 0.55923, saving model to model_weights.h5
# 225/225 [==============================] - 48s 212ms/step - loss: 1.2323 - accuracy: 0.5297 - val_loss: 1.1545 - val_accuracy: 0.5592
# Epoch 19/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2244 - accuracy: 0.5299
# Epoch 19: val_accuracy did not improve from 0.55923
# 225/225 [==============================] - 45s 198ms/step - loss: 1.2244 - accuracy: 0.5299 - val_loss: 1.2806 - val_accuracy: 0.5064
# Epoch 20/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2152 - accuracy: 0.5365
# Epoch 20: val_accuracy did not improve from 0.55923
# 225/225 [==============================] - 48s 214ms/step - loss: 1.2152 - accuracy: 0.5365 - val_loss: 1.1720 - val_accuracy: 0.5507
# Epoch 21/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2088 - accuracy: 0.5378
# Epoch 21: val_accuracy did not improve from 0.55923
# 225/225 [==============================] - 46s 205ms/step - loss: 1.2088 - accuracy: 0.5378 - val_loss: 1.2937 - val_accuracy: 0.4964
# Epoch 22/48
# 224/225 [============================>.] - ETA: 0s - loss: 1.1963 - accuracy: 0.5427
# Epoch 22: val_accuracy improved from 0.55923 to 0.57969, saving model to model_weights.h5
# 225/225 [==============================] - 46s 207ms/step - loss: 1.1964 - accuracy: 0.5426 - val_loss: 1.1059 - val_accuracy: 0.5797
# Epoch 23/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1848 - accuracy: 0.5454
# Epoch 23: val_accuracy did not improve from 0.57969
# 225/225 [==============================] - 46s 203ms/step - loss: 1.1848 - accuracy: 0.5454 - val_loss: 1.1822 - val_accuracy: 0.5507
# Epoch 24/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1771 - accuracy: 0.5514
# Epoch 24: val_accuracy improved from 0.57969 to 0.58182, saving model to model_weights.h5
# 225/225 [==============================] - 46s 205ms/step - loss: 1.1771 - accuracy: 0.5514 - val_loss: 1.1023 - val_accuracy: 0.5818
# Epoch 25/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1730 - accuracy: 0.5522
# Epoch 25: val_accuracy did not improve from 0.58182
# 225/225 [==============================] - 46s 204ms/step - loss: 1.1730 - accuracy: 0.5522 - val_loss: 1.1394 - val_accuracy: 0.5638
# Epoch 26/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1585 - accuracy: 0.5573
# Epoch 26: val_accuracy did not improve from 0.58182
# 225/225 [==============================] - 48s 215ms/step - loss: 1.1585 - accuracy: 0.5573 - val_loss: 1.1430 - val_accuracy: 0.5643
# Epoch 27/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1532 - accuracy: 0.5596
# Epoch 27: val_accuracy did not improve from 0.58182
# 225/225 [==============================] - 46s 205ms/step - loss: 1.1532 - accuracy: 0.5596 - val_loss: 1.1277 - val_accuracy: 0.5700
# Epoch 28/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1500 - accuracy: 0.5601
# Epoch 28: val_accuracy did not improve from 0.58182
# 225/225 [==============================] - 46s 203ms/step - loss: 1.1500 - accuracy: 0.5601 - val_loss: 1.1162 - val_accuracy: 0.5750
# Epoch 29/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1371 - accuracy: 0.5672
# Epoch 29: val_accuracy improved from 0.58182 to 0.60085, saving model to model_weights.h5
# 225/225 [==============================] - 46s 206ms/step - loss: 1.1371 - accuracy: 0.5672 - val_loss: 1.0555 - val_accuracy: 0.6009
# Epoch 30/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1355 - accuracy: 0.5678
# Epoch 30: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 46s 203ms/step - loss: 1.1355 - accuracy: 0.5678 - val_loss: 1.0875 - val_accuracy: 0.5902
# Epoch 31/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1261 - accuracy: 0.5728
# Epoch 31: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 45s 202ms/step - loss: 1.1261 - accuracy: 0.5728 - val_loss: 1.0878 - val_accuracy: 0.5895
# Epoch 32/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1189 - accuracy: 0.5743
# Epoch 32: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 47s 207ms/step - loss: 1.1189 - accuracy: 0.5743 - val_loss: 1.0847 - val_accuracy: 0.5949
# Epoch 33/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1114 - accuracy: 0.5815
# Epoch 33: val_accuracy did not improve from 0.60085
# 225/225 [==============================] - 45s 202ms/step - loss: 1.1114 - accuracy: 0.5815 - val_loss: 1.0918 - val_accuracy: 0.5960
# Epoch 34/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1092 - accuracy: 0.5796
# Epoch 34: val_accuracy improved from 0.60085 to 0.61051, saving model to model_weights.h5
# 225/225 [==============================] - 47s 207ms/step - loss: 1.1092 - accuracy: 0.5796 - val_loss: 1.0323 - val_accuracy: 0.6105
# Epoch 35/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1074 - accuracy: 0.5798
# Epoch 35: val_accuracy did not improve from 0.61051
# 225/225 [==============================] - 48s 212ms/step - loss: 1.1074 - accuracy: 0.5798 - val_loss: 1.0675 - val_accuracy: 0.5970
# Epoch 36/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0995 - accuracy: 0.5808
# Epoch 36: val_accuracy improved from 0.61051 to 0.61378, saving model to model_weights.h5
# 225/225 [==============================] - 47s 209ms/step - loss: 1.0995 - accuracy: 0.5808 - val_loss: 1.0389 - val_accuracy: 0.6138
# Epoch 37/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0942 - accuracy: 0.5856
# Epoch 37: val_accuracy did not improve from 0.61378
# 225/225 [==============================] - 47s 210ms/step - loss: 1.0942 - accuracy: 0.5856 - val_loss: 1.1682 - val_accuracy: 0.5567
# Epoch 38/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0920 - accuracy: 0.5884
# Epoch 38: val_accuracy did not improve from 0.61378
# 225/225 [==============================] - 47s 208ms/step - loss: 1.0920 - accuracy: 0.5884 - val_loss: 1.0474 - val_accuracy: 0.6067
# Epoch 39/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0880 - accuracy: 0.5846
# Epoch 39: val_accuracy did not improve from 0.61378
# 225/225 [==============================] - 47s 208ms/step - loss: 1.0880 - accuracy: 0.5846 - val_loss: 1.1672 - val_accuracy: 0.5507
# Epoch 40/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0846 - accuracy: 0.5858
# Epoch 40: val_accuracy did not improve from 0.61378
# 225/225 [==============================] - 47s 207ms/step - loss: 1.0846 - accuracy: 0.5858 - val_loss: 1.2017 - val_accuracy: 0.5364
# Epoch 41/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0758 - accuracy: 0.5922
# Epoch 41: val_accuracy improved from 0.61378 to 0.61889, saving model to model_weights.h5
# 225/225 [==============================] - 47s 211ms/step - loss: 1.0758 - accuracy: 0.5922 - val_loss: 1.0220 - val_accuracy: 0.6189
# Epoch 42/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0749 - accuracy: 0.5918
# Epoch 42: val_accuracy did not improve from 0.61889
# 225/225 [==============================] - 47s 209ms/step - loss: 1.0749 - accuracy: 0.5918 - val_loss: 1.0746 - val_accuracy: 0.5896
# Epoch 43/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0680 - accuracy: 0.5948
# Epoch 43: val_accuracy did not improve from 0.61889
# 225/225 [==============================] - 47s 211ms/step - loss: 1.0680 - accuracy: 0.5948 - val_loss: 1.2500 - val_accuracy: 0.5293
# Epoch 44/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0652 - accuracy: 0.5972
# Epoch 44: val_accuracy did not improve from 0.61889
# 225/225 [==============================] - 47s 211ms/step - loss: 1.0652 - accuracy: 0.5972 - val_loss: 1.1044 - val_accuracy: 0.5825
# Epoch 45/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0628 - accuracy: 0.5983
# Epoch 45: val_accuracy did not improve from 0.61889
# 225/225 [==============================] - 47s 209ms/step - loss: 1.0628 - accuracy: 0.5983 - val_loss: 1.0812 - val_accuracy: 0.5780
# Epoch 46/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0582 - accuracy: 0.6021
# Epoch 46: val_accuracy did not improve from 0.61889
# 225/225 [==============================] - 52s 230ms/step - loss: 1.0582 - accuracy: 0.6021 - val_loss: 1.1219 - val_accuracy: 0.5697
# Epoch 47/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0560 - accuracy: 0.6020
# Epoch 47: val_accuracy did not improve from 0.61889
# 225/225 [==============================] - 48s 214ms/step - loss: 1.0560 - accuracy: 0.6020 - val_loss: 1.0227 - val_accuracy: 0.6178
# Epoch 48/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0468 - accuracy: 0.6045
# Epoch 48: val_accuracy did not improve from 0.61889
# 225/225 [==============================] - 50s 224ms/step - loss: 1.0468 - accuracy: 0.6045 - val_loss: 1.1121 - val_accuracy: 0.5798

# %%
import matplotlib.pyplot as plt

# 훈련 및 검증 손실 및 정확도 시각화
plt.figure(figsize=(20, 10))

# 손실 그래프
plt.subplot(1, 2, 1)
plt.title('Training and Validation Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc='upper right')

# 정확도 그래프
plt.subplot(1, 2, 2)
plt.title('Training and Validation Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend()

plt.suptitle('Adam Optimizer', fontsize=20)
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import pandas as pd

# 테스트 데이터셋에 대한 모델의 예측 생성
y_pred = model.predict(test_generator)
ypred_class = np.argmax(y_pred, axis=1)

# 실제 레이블 추출
ytest_class = test_generator.classes

# 혼동 행렬 계산
conf_mat = confusion_matrix(ytest_class, ypred_class)

# 레이블 설정
label = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# 혼동 행렬을 데이터프레임으로 시각화
table = pd.DataFrame(conf_mat, columns=label, index=label)
table
# Out:
# 56/56 [==============================] - 4s 61ms/step
#           angry  disgust  fear  happy  neutral  sad  surprise
# angry       442        1    22     32      267  181        15
# disgust      40        6     9      1       17   33         5
# fear        154        0   238     22      238  265       101
# happy        63        2    19   1375      227   99        40
# neutral      35        0    25     59      850  224        23
# sad          74        1    32     26      386  612         8
# surprise     34        0    65     35       61   25       577

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# 테스트 데이터셋에 대한 모델의 예측 생성
predictions = model.predict(test_generator)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = list(test_generator.class_indices.keys())

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # 정규화
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# 혼동 행렬 계산
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# 정규화된 혼동 행렬 시각화
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()
# Out:
# 56/56 [==============================] - 3s 48ms/step

# %%
# 새로운 테스트 데이터를 이용하여 CNN 모델 평가하기

from keras.preprocessing.image import ImageDataGenerator

# 경로 설정
new_data_path = '/content/drive/MyDrive/ESAA_OB/test'

# ImageDataGenerator를 사용하여 데이터 로딩 및 전처리 설정
new_data_generator = ImageDataGenerator(rescale=1./255.)

# 새로운 데이터셋을 생성
new_data_generator = new_data_generator.flow_from_directory(
    new_data_path,
    target_size=(pic_size, pic_size),
    color_mode="rgb",
    batch_size=128,
    class_mode="categorical",
    shuffle=False  # 셔플 여부는 모델 평가 시에는 중요 X
)

# 새로운 테스트 데이터셋에서 모델 평가
new_data_score = model.evaluate(new_data_generator, verbose=0)
print('New Data Test loss:', new_data_score[0])
print('New Data Test accuracy:', new_data_score[1])
# Out:
# Found 46 images belonging to 7 classes.
# New Data Test loss: 3.182792901992798
# New Data Test accuracy: 0.239130437374115

# %% [markdown]
# * disgust 분류를 잘 못함 (angry나 neutral로 분류하는 경우가 많음.)

# %% [markdown]
# # 1. densenet -121 모델

# %%
from tensorflow.keras.applications import Xception, MobileNetV2, DenseNet121, EfficientNetB2, ResNet101,VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np

channels = 3
num_classes = 7
batch_size = 128
picture_size=48

# %%
def get_callbacks(model_name):
    callbacks = []

    # Use correct syntax for ModelCheckpoint
    checkpoint = ModelCheckpoint(filepath=f'model.{model_name}.h5', verbose=1, monitor='val_accuracy', mode='max')
    callbacks.append(checkpoint)

    # Import ReduceLROnPlateau if not imported earlier
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)
    callbacks.append(reduce_lr)

    # Import EarlyStopping if not imported earlier
    early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True, verbose=1)
    callbacks.append(early_stopping)

    return callbacks

# %% [markdown]
# 모델을 사용하는데 필요한 패키지들을 불러옴
# >
# 모델의 성능을 최적화하고 과적합을 방지하기 위해 콜백 함수 사용
# >
# 1. ModelCheckpoint: 모델의 가중치 저장. monitor='val_accuracy'는 검증 데이터에 대한 정확도를 기준으로 모델의 성능을 평가한다는 의미, mode='max'는 정확도가 최대일 때 모델을 저장하는 것, verbose=1은 훈련 과정 중 상세한 정보 출력하는 것.
# >
# 2. ReduceLROnPlateau: 모델이 학습하는 동안의 학습률(learning rate) 조정. monitor='val_loss'는 검증 데이터의 손실을 기준으로 학습률을 조절하는 것, factor=0.2는 학습률을 줄일 때 20%까지 감소시킨다는 것, patience=3은 3번의 에폭(epoch) 동안 개선이 없을 경우 학습률을 줄이는 것, min_lr=1e-6은 학습률의 최소값.
# >
# 3. EarlyStopping: 특정 조건이 충족될 때 훈련을 조기에 중단시키는 것. monitor='val_loss'는 검증 데이터의 손실을 기준으로 조기 중단 여부를 결정, patience=7은 7번의 에폭 동안 개선이 없을 경우 훈련을 중단하라는 것, restore_best_weights=True는 가장 좋은 가중치로 모델을 복원.

# %% [markdown]
# DenseNet121은 컴퓨터 비전 분야에서 사용되는 심층 신경망 아키텍처의 한 종류("Densely Connected Convolutional Networks" + 121개의 층)
# >
# DenseNet은 특히 이미지 분류, 객체 탐지 및 세분화 작업과 같은 컴퓨터 비전 태스크에 널리 사용되며, 그 중 DenseNet121은 균형 잡힌 깊이와 복잡성으로 인해 많은 실용적인 응용 분야에서 인기가 높음.
# >
# DenseNet 아키텍처의 주요 특징은 층 간의 '밀집 연결(Dense Connection)'로, 기존의 컨볼루션 신경망(CNN)에서는 각 층이 이전 층의 출력만을 입력으로 받지만, DenseNet에서는 각 층이 이전 모든 층으로부터의 출력을 입력으로 받음
# >
# 장점
# 1. 특징 재사용: 각 층이 이전 모든 층의 출력에 접근할 수 있기 때문에, 특징(feature)들이 네트워크 전반에 걸쳐 재사용될 수 있음
#
# 2. 효율적인 특징 전달: 밀집 연결은 각 층으로의 특징 전달을 향상시켜, 네트워크가 더 효율적으로 학습될 수 있음
#
# 3. 파라미터 효율성: 각 층이 이전 층들의 출력을 직접적으로 활용함으로써 필요한 파라미터의 수가 감소하므로, 모델이 더 적은 파라미터로도 효과적인 학습을 할 수 있게 됨

# %%
# Create DenseNet121 base model
base_model = DenseNet121(input_shape=(picture_size, picture_size, 3), include_top=False, weights='imagenet')

base_model.trainable = True

# Add custom layers on top of the base model
x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.Dense(256, activation='relu')(x)
predictions = layers.Dense(num_classes, activation='softmax')(x)

# Create the model
model_DenseNet121 = Model(inputs=base_model.input, outputs=predictions)

model_DenseNet121.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Get callbacks
callbacks = get_callbacks('DenseNet121')

# %% [markdown]
# DenseNet121 기본 모델 생성: DenseNet121 함수를 사용하여 기본 모델을 생성합니다. input_shape는 모델이 받아들일 입력 이미지의 크기를 정의합니다. include_top=False는 네트워크의 최상위 층(일반적으로 분류기 층)을 포함하지 않겠다는 의미입니다. weights='imagenet'는 ImageNet 데이터로 미리 훈련된 가중치를 사용하겠다는 것을 의미합니다.
#
# 1. 모델 학습 설정: base_model.trainable = True는 전체 모델의 가중치가 훈련 과정에서 업데이트될 수 있게 합니다.
#
# 2. 커스텀 층 추가: GlobalAveragePooling2D는 특징 맵의 글로벌 평균 풀링을 수행합니다. 그 후, Dense 층을 사용하여 256개의 뉴런과 ReLU 활성화 함수를 가진 층을 추가합니다. 마지막으로, num_classes개의 출력 뉴런을 가진 Dense 층을 추가하고, softmax 활성화 함수를 사용하여 분류를 수행합니다.
#
# 3. 모델 생성: Model 함수를 사용하여 입력으로 base_model.input을, 출력으로 predictions을 가지는 새로운 모델을 생성합니다.
#
# 4. 모델 컴파일: 생성한 모델을 compile 메서드로 컴파일합니다. 이 때, 옵티마이저로 Adam을 사용하고, 학습률은 0.001로 설정합니다. 손실 함수로는 categorical_crossentropy를, 성능 지표로는 accuracy를 사용합니다.
#
# 5. 콜백 함수 가져오기: 이전에 정의된 get_callbacks 함수를 사용하여 학습 중 적용할 콜백들의 리스트를 가져옵니다. 이 리스트는 모델 체크포인트 저장, 학습률 감소, 조기 종료 등의 기능을 포함할 수 있습니다.

# %%
# Train the model
history_DenseNet121 = model_DenseNet121.fit(
    train_generator,
    epochs=48,
    validation_data=test_generator,
    callbacks=callbacks
    # steps_per_epoch와 validation_steps는 필요에 따라 추가하거나 생략할 수 있음
)
# Out:
# Epoch 1/48
# 226/226 [==============================] - ETA: 0s - loss: 1.6854 - accuracy: 0.3300
# Epoch 1: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 132s 275ms/step - loss: 1.6854 - accuracy: 0.3300 - val_loss: 2.9888 - val_accuracy: 0.3692 - lr: 0.0010
# Epoch 2/48
# 226/226 [==============================] - ETA: 0s - loss: 1.3713 - accuracy: 0.4769
# Epoch 2: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 60s 265ms/step - loss: 1.3713 - accuracy: 0.4769 - val_loss: 1.8412 - val_accuracy: 0.3497 - lr: 0.0010
# Epoch 3/48
# 226/226 [==============================] - ETA: 0s - loss: 1.2628 - accuracy: 0.5171
# Epoch 3: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 262ms/step - loss: 1.2628 - accuracy: 0.5171 - val_loss: 1.2945 - val_accuracy: 0.5098 - lr: 0.0010
# Epoch 4/48
# 226/226 [==============================] - ETA: 0s - loss: 1.2199 - accuracy: 0.5347
# Epoch 4: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 58s 257ms/step - loss: 1.2199 - accuracy: 0.5347 - val_loss: 1.2574 - val_accuracy: 0.5324 - lr: 0.0010
# Epoch 5/48
# 226/226 [==============================] - ETA: 0s - loss: 1.2016 - accuracy: 0.5462
# Epoch 5: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 61s 268ms/step - loss: 1.2016 - accuracy: 0.5462 - val_loss: 1.1150 - val_accuracy: 0.5832 - lr: 0.0010
# Epoch 6/48
# 226/226 [==============================] - ETA: 0s - loss: 1.1685 - accuracy: 0.5566
# Epoch 6: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 263ms/step - loss: 1.1685 - accuracy: 0.5566 - val_loss: 3.7720 - val_accuracy: 0.5238 - lr: 0.0010
# Epoch 7/48
# 226/226 [==============================] - ETA: 0s - loss: 1.1477 - accuracy: 0.5658
# Epoch 7: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 262ms/step - loss: 1.1477 - accuracy: 0.5658 - val_loss: 1.1673 - val_accuracy: 0.5593 - lr: 0.0010
# Epoch 8/48
# 226/226 [==============================] - ETA: 0s - loss: 1.1238 - accuracy: 0.5756
# Epoch 8: saving model to model.DenseNet121.h5
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 226/226 [==============================] - 60s 264ms/step - loss: 1.1238 - accuracy: 0.5756 - val_loss: 1.1468 - val_accuracy: 0.5870 - lr: 0.0010
# Epoch 9/48
# 226/226 [==============================] - ETA: 0s - loss: 1.0323 - accuracy: 0.6109
# Epoch 9: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 61s 272ms/step - loss: 1.0323 - accuracy: 0.6109 - val_loss: 1.0104 - val_accuracy: 0.6182 - lr: 2.0000e-04
# Epoch 10/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9970 - accuracy: 0.6221
# Epoch 10: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 60s 264ms/step - loss: 0.9970 - accuracy: 0.6221 - val_loss: 0.9884 - val_accuracy: 0.6337 - lr: 2.0000e-04
# Epoch 11/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9847 - accuracy: 0.6271
# Epoch 11: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 58s 258ms/step - loss: 0.9847 - accuracy: 0.6271 - val_loss: 0.9681 - val_accuracy: 0.6393 - lr: 2.0000e-04
# Epoch 12/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9718 - accuracy: 0.6310
# Epoch 12: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 61s 269ms/step - loss: 0.9718 - accuracy: 0.6310 - val_loss: 0.9712 - val_accuracy: 0.6387 - lr: 2.0000e-04
# Epoch 13/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9626 - accuracy: 0.6338
# Epoch 13: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 60s 266ms/step - loss: 0.9626 - accuracy: 0.6338 - val_loss: 0.9602 - val_accuracy: 0.6480 - lr: 2.0000e-04
# Epoch 14/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9499 - accuracy: 0.6424
# Epoch 14: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 263ms/step - loss: 0.9499 - accuracy: 0.6424 - val_loss: 0.9420 - val_accuracy: 0.6506 - lr: 2.0000e-04
# Epoch 15/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9427 - accuracy: 0.6474
# Epoch 15: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 262ms/step - loss: 0.9427 - accuracy: 0.6474 - val_loss: 0.9895 - val_accuracy: 0.6282 - lr: 2.0000e-04
# Epoch 16/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9388 - accuracy: 0.6438
# Epoch 16: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 263ms/step - loss: 0.9388 - accuracy: 0.6438 - val_loss: 0.9922 - val_accuracy: 0.6398 - lr: 2.0000e-04
# Epoch 17/48
# 226/226 [==============================] - ETA: 0s - loss: 0.9264 - accuracy: 0.6507
# Epoch 17: saving model to model.DenseNet121.h5
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 226/226 [==============================] - 59s 262ms/step - loss: 0.9264 - accuracy: 0.6507 - val_loss: 0.9450 - val_accuracy: 0.6476 - lr: 2.0000e-04
# Epoch 18/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8933 - accuracy: 0.6640
# Epoch 18: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 57s 252ms/step - loss: 0.8933 - accuracy: 0.6640 - val_loss: 0.9258 - val_accuracy: 0.6560 - lr: 4.0000e-05
# Epoch 19/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8798 - accuracy: 0.6683
# Epoch 19: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 260ms/step - loss: 0.8798 - accuracy: 0.6683 - val_loss: 0.9213 - val_accuracy: 0.6581 - lr: 4.0000e-05
# Epoch 20/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8757 - accuracy: 0.6705
# Epoch 20: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 262ms/step - loss: 0.8757 - accuracy: 0.6705 - val_loss: 0.9150 - val_accuracy: 0.6620 - lr: 4.0000e-05
# Epoch 21/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8666 - accuracy: 0.6726
# Epoch 21: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 58s 257ms/step - loss: 0.8666 - accuracy: 0.6726 - val_loss: 0.9233 - val_accuracy: 0.6615 - lr: 4.0000e-05
# Epoch 22/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8635 - accuracy: 0.6733
# Epoch 22: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 261ms/step - loss: 0.8635 - accuracy: 0.6733 - val_loss: 0.9274 - val_accuracy: 0.6630 - lr: 4.0000e-05
# Epoch 23/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8630 - accuracy: 0.6772
# Epoch 23: saving model to model.DenseNet121.h5
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 226/226 [==============================] - 59s 258ms/step - loss: 0.8630 - accuracy: 0.6772 - val_loss: 0.9220 - val_accuracy: 0.6591 - lr: 4.0000e-05
# Epoch 24/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8484 - accuracy: 0.6805
# Epoch 24: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 263ms/step - loss: 0.8484 - accuracy: 0.6805 - val_loss: 0.9165 - val_accuracy: 0.6605 - lr: 8.0000e-06
# Epoch 25/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8482 - accuracy: 0.6803
# Epoch 25: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 60s 264ms/step - loss: 0.8482 - accuracy: 0.6803 - val_loss: 0.9145 - val_accuracy: 0.6611 - lr: 8.0000e-06
# Epoch 26/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8462 - accuracy: 0.6787
# Epoch 26: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 58s 256ms/step - loss: 0.8462 - accuracy: 0.6787 - val_loss: 0.9160 - val_accuracy: 0.6620 - lr: 8.0000e-06
# Epoch 27/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8454 - accuracy: 0.6823
# Epoch 27: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 60s 267ms/step - loss: 0.8454 - accuracy: 0.6823 - val_loss: 0.9185 - val_accuracy: 0.6632 - lr: 8.0000e-06
# Epoch 28/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8446 - accuracy: 0.6827
# Epoch 28: saving model to model.DenseNet121.h5
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 226/226 [==============================] - 61s 268ms/step - loss: 0.8446 - accuracy: 0.6827 - val_loss: 0.9165 - val_accuracy: 0.6633 - lr: 8.0000e-06
# Epoch 29/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8395 - accuracy: 0.6809
# Epoch 29: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 59s 260ms/step - loss: 0.8395 - accuracy: 0.6809 - val_loss: 0.9161 - val_accuracy: 0.6635 - lr: 1.6000e-06
# Epoch 30/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8397 - accuracy: 0.6833
# Epoch 30: saving model to model.DenseNet121.h5
# 226/226 [==============================] - 60s 267ms/step - loss: 0.8397 - accuracy: 0.6833 - val_loss: 0.9154 - val_accuracy: 0.6633 - lr: 1.6000e-06
# Epoch 31/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8392 - accuracy: 0.6838
# Epoch 31: saving model to model.DenseNet121.h5
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1e-06.
# 226/226 [==============================] - 60s 265ms/step - loss: 0.8392 - accuracy: 0.6838 - val_loss: 0.9157 - val_accuracy: 0.6649 - lr: 1.6000e-06
# Epoch 32/48
# 226/226 [==============================] - ETA: 0s - loss: 0.8390 - accuracy: 0.6851
# Epoch 32: saving model to model.DenseNet121.h5
# Restoring model weights from the end of the best epoch: 25.
# 226/226 [==============================] - 59s 263ms/step - loss: 0.8390 - accuracy: 0.6851 - val_loss: 0.9162 - val_accuracy: 0.6646 - lr: 1.0000e-06
# Epoch 32: early stopping

# %%
tr_acc = history_DenseNet121.history['accuracy']
tr_loss = history_DenseNet121.history['loss']
val_acc = history_DenseNet121.history['val_accuracy']
val_loss = history_DenseNet121.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import pandas as pd

# 테스트 데이터셋에 대한 모델의 예측 생성
y_pred = model_DenseNet121.predict(test_generator)
ypred_class = np.argmax(y_pred, axis=1)

# 실제 레이블 추출
ytest_class = test_generator.classes

# 혼동 행렬 계산
conf_mat = confusion_matrix(ytest_class, ypred_class)

# 레이블 설정
label = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# 혼동 행렬을 데이터프레임으로 시각화
table = pd.DataFrame(conf_mat, columns=label, index=label)
table
# Out:
# 56/56 [==============================] - 6s 64ms/step
#           angry  disgust  fear  happy  neutral  sad  surprise
# angry       565        9    66     30      129  139        22
# disgust      31       57     4      1        1   13         4
# fear        176        6   401     26      134  200        75
# happy        44        2    25   1571      107   41        35
# neutral      66        4    33     69      851  168        25
# sad         116        4    84     31      262  633         9
# surprise     25        2    85     49       28   15       593

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# 테스트 데이터셋에 대한 모델의 예측 생성
predictions = model_DenseNet121.predict(test_generator)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = list(test_generator.class_indices.keys())

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # 정규화
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# 혼동 행렬 계산
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# 정규화된 혼동 행렬 시각화
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()
# Out:
# 56/56 [==============================] - 4s 77ms/step

# %%
# 새로운 테스트 데이터를 이용하여 Densenet121 모델 평가하기

# 경로 설정
new_data_path = '/content/drive/MyDrive/ESAA_OB/test'
/content/drive/MyDrive/2023-2/test

# ImageDataGenerator를 사용하여 데이터 로딩 및 전처리 설정
new_data_generator = ImageDataGenerator(rescale=1./255.)

# 새로운 데이터셋 생성
new_data_generator = new_data_generator.flow_from_directory(
    new_data_path,
    target_size=(picture_size, picture_size),
    color_mode="rgb",
    batch_size=128,
    class_mode="categorical",
    shuffle=False  # 셔플 여부는 모델 평가 시에는 중요 X
)

# 새로운 테스트 데이터셋에서 모델 평가
new_data_score = model_DenseNet121.evaluate(new_data_generator, verbose=0)
print('New Data Test loss:', new_data_score[0])
print('New Data Test accuracy:', new_data_score[1])
# Out:
# Found 46 images belonging to 7 classes.
# New Data Test loss: 2.7871854305267334
# New Data Test accuracy: 0.28260868787765503
